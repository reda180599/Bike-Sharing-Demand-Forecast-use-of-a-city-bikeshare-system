# %% [markdown]
# ## Bike Sharing Demand Forecast use of a city bikeshare system

# %% [markdown]
# (You Can Get Data From : )[https://www.kaggle.com/competitions/bike-sharing-demand/]

# %% [markdown]
# ### Import Libararoes

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib

from sklearn.model_selection import train_test_split

import math
# Out:
# Using matplotlib backend: <object object at 0x0000019D9784E710>

# %% [markdown]
# ### Reading the data

# %%
data = pd.read_csv('train.csv')
data
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %% [markdown]
# ### Explore Data

# %%
data_copy = data.copy()

data_copy.head(3)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32

# %%
data_copy = data_copy.drop(['datetime'], axis=1)

# %%
data_copy
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 0           1        0           0        1   9.84  14.395        81
# 1           1        0           0        1   9.02  13.635        80
# 2           1        0           0        1   9.02  13.635        80
# 3           1        0           0        1   9.84  14.395        75
# 4           1        0           0        1   9.84  14.395        75
# ...       ...      ...         ...      ...    ...     ...       ...
# 10881       4        0           1        1  15.58  19.695        50
# 10882       4        0           1        1  14.76  17.425        57
# 10883       4        0           1        1  13.94  15.910        61
# 10884       4        0           1        1  13.94  17.425        61
# 10885       4        0           1        1  13.12  16.665        66
#
#        windspeed  casual  registered  count
# 0         0.0000       3          13     16
# 1         0.0000       8          32     40
# ...

# %% [markdown]
# # fnd null values
#
# data_copy.isnull().sum()

# %% [markdown]
# ### Analyze Data

# %%
sns.heatmap(data_copy.isnull())
# Out:
# <AxesSubplot:>

# %%
data_copy.hist(rwidth = .9)

plt.show()

# %% [markdown]
# #### Data Visualization

# %% [markdown]
# #### 1- visualize the continuos features vs Demand or Count of bikes

# %%
#visualize the tempreeture vs Demand or Count of bikes

plt.subplot(3, 3, 1)
plt.title('tempreeture vs Demand or Count')
plt.scatter(data_copy['temp'], data_copy['count'])  # spread of data between two variables
plt.show()

# %%
#visualize the windspeed vs Demand or Count of bikes

plt.subplot(3, 3, 2)
plt.title('windspeed vs Demand or Count')
plt.scatter(data_copy['windspeed'], data_copy['count'])  # spread of data between two variables
plt.show()

# %%
#visualize the humidity vs Demand or Count of bikes

plt.subplot(2, 2, 3)
plt.title('humidity vs Demand or Count')
plt.scatter(data_copy['humidity'], data_copy['count'])  # spread of data between two variables
plt.show()

# %%
#visualize the registered vs Demand or Count of bikes

plt.subplot(3, 3, 4)
plt.title('registered vs Demand or Count')
plt.scatter(data_copy['registered'], data_copy['count'])  # spread of data between two variables
plt.show()

# %% [markdown]
# #### 2- Categorical the features vs Demand or Count of bikes

# %%
#Mean of Demand per season
season = data_copy['season'].unique()
demand_average1 = data_copy.groupby('season').mean()['count']

plt.subplot(3,3,5)
plt.title('Mean of Demand per season')
plt.bar(season, demand_average1)
# Out:
# <BarContainer object of 4 artists>

# %%
#Mean of Demand per workingday
workingday = data_copy['workingday'].unique()
demand_average2 = data_copy.groupby('workingday').mean()['count']

plt.subplot(3,3,6)
plt.title('Mean of Demand per workingday')
plt.bar(workingday, demand_average2)
# Out:
# <BarContainer object of 2 artists>

# %%
#Mean of Demand per weather
weather = data_copy['weather'].unique()
demand_average3 = data_copy.groupby('weather').mean()['count']

plt.subplot(3,3,7)
plt.title('Mean of Demand per weather')
plt.bar(weather, demand_average3)
# Out:
# <BarContainer object of 4 artists>

# %%
#Mean of Demand per holiday
holiday = data_copy['holiday'].unique()
demand_average4 = data_copy.groupby('holiday').mean()['count']

plt.subplot(3,3,8)
plt.title('Mean of Demand per holiday')
plt.bar(holiday, demand_average4)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Reda Ibrahim\AppData\Local\Temp\ipykernel_13720\3006889588.py:8: UserWarning: tight_layout not applied: number of rows in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %% [markdown]
# #### in the previous examples (visualization you can use for loop)

# %%
'''
newDataVisualize = ['season', 'holiday', 'weather', 'workingday']

counter = 1
for i in newDataVisualize:
    x = data_copy[i].unique()
    demand_average = data_copy.groupby(i).mean()['count']
    plt.subplot(2,2,counter)
    counter += 1
    plt.bar(x, demand_average)
    plt.show()

'''
# Out:
# "\nnewDataVisualize = ['season', 'holiday', 'weather', 'workingday']\n\ncounter = 1\nfor i in newDataVisualize:\n    x = data_copy[i].unique()\n    demand_average = data_copy.groupby(i).mean()['count']\n    plt.subplot(2,2,counter)\n    counter += 1\n    plt.bar(x, demand_average)\n    plt.show()\n\n"

# %% [markdown]
# ## Check the outliers in data

# %%
data_copy['count'].quantile([.25, .5,.75])
# Out:
# 0.25     42.0
# 0.50    145.0
# 0.75    284.0
# Name: count, dtype: float64

# %%
data_copy['count'].std()
# Out:
# 181.14445383028496

# %%
data_copy['count'].mode()
# Out:
# 0    5
# Name: count, dtype: int64

# %%
data_copy['count'].describe()
# Out:
# count    10886.000000
# mean       191.574132
# std        181.144454
# min          1.000000
# 25%         42.000000
# 50%        145.000000
# 75%        284.000000
# max        977.000000
# Name: count, dtype: float64

# %% [markdown]
# ## Check multiple Linear Regression Assumption

# %%
#using corr function   ---- using this you can find the degree of relationship between columns

correlation = data_copy[['temp', 'atemp', 'humidity', 'windspeed', 'count']].corr()

correlation
# Out:
#                temp     atemp  humidity  windspeed     count
# temp       1.000000  0.984948 -0.064949  -0.017852  0.394454
# atemp      0.984948  1.000000 -0.043536  -0.057473  0.389784
# humidity  -0.064949 -0.043536  1.000000  -0.318607 -0.317371
# windspeed -0.017852 -0.057473 -0.318607   1.000000  0.101369
# count      0.394454  0.389784 -0.317371   0.101369  1.000000

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <AxesSubplot:title={'center':'Mean of Demand per holiday'}>

# %%
data_copy = data_copy.drop(['atemp', 'windspeed'], axis=1)

# %%
data_copy
# Out:
#        season  holiday  workingday  weather   temp  humidity  casual  \
# 0           1        0           0        1   9.84        81       3
# 1           1        0           0        1   9.02        80       8
# 2           1        0           0        1   9.02        80       5
# 3           1        0           0        1   9.84        75       3
# 4           1        0           0        1   9.84        75       0
# ...       ...      ...         ...      ...    ...       ...     ...
# 10881       4        0           1        1  15.58        50       7
# 10882       4        0           1        1  14.76        57      10
# 10883       4        0           1        1  13.94        61       4
# 10884       4        0           1        1  13.94        61      12
# 10885       4        0           1        1  13.12        66       4
#
#        registered  count
# 0              13     16
# 1              32     40
# 2              27     32
# 3              10     13
# ...

# %%
data_copy = data_copy.drop(['registered', 'casual'], axis=1)

# %%
data_copy
# Out:
#        season  holiday  workingday  weather   temp  humidity  count
# 0           1        0           0        1   9.84        81     16
# 1           1        0           0        1   9.02        80     40
# 2           1        0           0        1   9.02        80     32
# 3           1        0           0        1   9.84        75     13
# 4           1        0           0        1   9.84        75      1
# ...       ...      ...         ...      ...    ...       ...    ...
# 10881       4        0           1        1  15.58        50    336
# 10882       4        0           1        1  14.76        57    241
# 10883       4        0           1        1  13.94        61    168
# 10884       4        0           1        1  13.94        61    129
# 10885       4        0           1        1  13.12        66     88
#
# [10886 rows x 7 columns]

# %%
# find autocorreleation of count

df = pd.to_numeric(data_copy['count'], downcast='float')

plt.acorr(df, maxlags = 12)
plt.show()  ## we noticed that the correlation is high and that is not valid in multiple linear regression

# %% [markdown]
# ### Create or modify new features

# %%
# Log normalize the feature 'Count' to convert it to normal distribution

df1 = data_copy['count']

df2 = np.log(df1)

df2
# Out:
# 0        2.772589
# 1        3.688879
# 2        3.465736
# 3        2.564949
# 4        0.000000
#            ...
# 10881    5.817111
# 10882    5.484797
# 10883    5.123964
# 10884    4.859812
# 10885    4.477337
# Name: count, Length: 10886, dtype: float64

# %%
plt.figure()

df1.hist()
# Out:
# <AxesSubplot:>

# %%
plt.figure()
df2.hist()
# Out:
# <AxesSubplot:>

# %%
data_copy['count'] = df2

data_copy
# Out:
#        season  holiday  workingday  weather   temp  humidity     count
# 0           1        0           0        1   9.84        81  2.772589
# 1           1        0           0        1   9.02        80  3.688879
# 2           1        0           0        1   9.02        80  3.465736
# 3           1        0           0        1   9.84        75  2.564949
# 4           1        0           0        1   9.84        75  0.000000
# ...       ...      ...         ...      ...    ...       ...       ...
# 10881       4        0           1        1  15.58        50  5.817111
# 10882       4        0           1        1  14.76        57  5.484797
# 10883       4        0           1        1  13.94        61  5.123964
# 10884       4        0           1        1  13.94        61  4.859812
# 10885       4        0           1        1  13.12        66  4.477337
#
# [10886 rows x 7 columns]

# %%
#we can short the prevous by --- data_copy['count'] = np.log(data_copy['count'])

# %% [markdown]
# ### Solve the problem of High Autocorrelation

# %%
# Shift the count by 3 lags

dfNew1 = data_copy['count'].shift(+1).to_frame()  # 1 number of shifts

dfNew1.columns = ['Count_1']

dfNew2 = data_copy['count'].shift(+2).to_frame()  # 2 number of shifts

dfNew2.columns = ['Count_2']

dfNew3 = data_copy['count'].shift(+3).to_frame() # 3 number of shifts

dfNew3.columns = ['Count_3']


data_copy_lags = pd.concat([data_copy, dfNew1, dfNew2, dfNew3], axis= 1)

# %%
data_copy_lags
# Out:
#        season  holiday  workingday  weather   temp  humidity     count  \
# 0           1        0           0        1   9.84        81  2.772589
# 1           1        0           0        1   9.02        80  3.688879
# 2           1        0           0        1   9.02        80  3.465736
# 3           1        0           0        1   9.84        75  2.564949
# 4           1        0           0        1   9.84        75  0.000000
# ...       ...      ...         ...      ...    ...       ...       ...
# 10881       4        0           1        1  15.58        50  5.817111
# 10882       4        0           1        1  14.76        57  5.484797
# 10883       4        0           1        1  13.94        61  5.123964
# 10884       4        0           1        1  13.94        61  4.859812
# 10885       4        0           1        1  13.12        66  4.477337
#
#         Count_1   Count_2   Count_3
# 0           NaN       NaN       NaN
# 1      2.772589       NaN       NaN
# ...

# %%
# count_1, count_2, count_3 === means three copy of count but in last times

# %%
data_copy_lags = data_copy_lags.dropna()

# %%
data_copy_lags
# Out:
#        season  holiday  workingday  weather   temp  humidity     count  \
# 3           1        0           0        1   9.84        75  2.564949
# 4           1        0           0        1   9.84        75  0.000000
# 5           1        0           0        2   9.84        75  0.000000
# 6           1        0           0        1   9.02        80  0.693147
# 7           1        0           0        1   8.20        86  1.098612
# ...       ...      ...         ...      ...    ...       ...       ...
# 10881       4        0           1        1  15.58        50  5.817111
# 10882       4        0           1        1  14.76        57  5.484797
# 10883       4        0           1        1  13.94        61  5.123964
# 10884       4        0           1        1  13.94        61  4.859812
# 10885       4        0           1        1  13.12        66  4.477337
#
#         Count_1   Count_2   Count_3
# 3      3.465736  3.688879  2.772589
# 4      2.564949  3.465736  3.688879
# ...

# %%
# ----------------------------- Done ------------------------------------# 

#data_copy_lags['season'].value_counts()

# %% [markdown]
# ### Now we can use the new data in predicting the count (the demand of the bikles)

# %%
# we create Dummy variables  --- Convert all the columns to independent columns [Categorical Data Exactly] 
# such as convert the season to four columns

# %%
# how to make this by using astype functon

data_copy_lags['season'] = data_copy_lags['season'].astype('category')
data_copy_lags['holiday'] = data_copy_lags['holiday'].astype('category')
data_copy_lags['weather'] = data_copy_lags['weather'].astype('category')
data_copy_lags['workingday'] = data_copy_lags['workingday'].astype('category')


data_copy_lags = pd.get_dummies(data_copy_lags, drop_first=True)
# Out:
# C:\Users\Reda Ibrahim\AppData\Local\Temp\ipykernel_13720\141325828.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_copy_lags['season'] = data_copy_lags['season'].astype('category')
# C:\Users\Reda Ibrahim\AppData\Local\Temp\ipykernel_13720\141325828.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_copy_lags['holiday'] = data_copy_lags['holiday'].astype('category')
# C:\Users\Reda Ibrahim\AppData\Local\Temp\ipykernel_13720\141325828.py:5: SettingWithCopyWarning:
# ...

# %%
data_copy_lags
# Out:
#         temp  humidity     count   Count_1   Count_2   Count_3  season_2  \
# 3       9.84        75  2.564949  3.465736  3.688879  2.772589         0
# 4       9.84        75  0.000000  2.564949  3.465736  3.688879         0
# 5       9.84        75  0.000000  0.000000  2.564949  3.465736         0
# 6       9.02        80  0.693147  0.000000  0.000000  2.564949         0
# 7       8.20        86  1.098612  0.693147  0.000000  0.000000         0
# ...      ...       ...       ...       ...       ...       ...       ...
# 10881  15.58        50  5.817111  6.343880  6.331502  5.811141         0
# 10882  14.76        57  5.484797  5.817111  6.343880  6.331502         0
# 10883  13.94        61  5.123964  5.484797  5.817111  6.343880         0
# 10884  13.94        61  4.859812  5.123964  5.484797  5.817111         0
# 10885  13.12        66  4.477337  4.859812  5.123964  5.484797         0
#
#        season_3  season_4  holiday_1  workingday_1  weather_2  weather_3  \
# ...

# %% [markdown]
# ### Now create train and Test

# %%
# Count is time series type of data

Y = data_copy_lags['count'] # predicted coulumn
X = data_copy_lags.drop(['count'], axis=1)  # depended values (Other features)

# %%
X
# Out:
#         temp  humidity   Count_1   Count_2   Count_3  season_2  season_3  \
# 3       9.84        75  3.465736  3.688879  2.772589         0         0
# 4       9.84        75  2.564949  3.465736  3.688879         0         0
# 5       9.84        75  0.000000  2.564949  3.465736         0         0
# 6       9.02        80  0.000000  0.000000  2.564949         0         0
# 7       8.20        86  0.693147  0.000000  0.000000         0         0
# ...      ...       ...       ...       ...       ...       ...       ...
# 10881  15.58        50  6.343880  6.331502  5.811141         0         0
# 10882  14.76        57  5.817111  6.343880  6.331502         0         0
# 10883  13.94        61  5.484797  5.817111  6.343880         0         0
# 10884  13.94        61  5.123964  5.484797  5.817111         0         0
# 10885  13.12        66  4.859812  5.123964  5.484797         0         0
#
#        season_4  holiday_1  workingday_1  weather_2  weather_3  weather_4
# ...

# %%
Y
# Out:
# 3        2.564949
# 4        0.000000
# 5        0.000000
# 6        0.693147
# 7        1.098612
#            ...
# 10881    5.817111
# 10882    5.484797
# 10883    5.123964
# 10884    4.859812
# 10885    4.477337
# Name: count, Length: 10883, dtype: float64

# %%
#--------------------------------- Now we have divided the data to dependent and independent ------------------#

# %% [markdown]
# ### --------------------------------- Now we have divided the data to train and test ------------------

# %%
train_size = .7 * len(X)

# %%
train_size
# Out:
# 7618.099999999999

# %%
train_size = int(train_size)
train_size
# Out:
# 7618

# %%
x_train = X.values[0:train_size]
x_train
# Out:
# array([[ 9.84      , 75.        ,  3.4657359 , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 9.84      , 75.        ,  2.56494936, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 9.84      , 75.        ,  0.        , ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [28.7       , 54.        ,  6.74051936, ...,  0.        ,
#          0.        ,  0.        ],
#        [27.06      , 65.        ,  6.38012254, ...,  0.        ,
#          0.        ,  0.        ],
#        [26.24      , 73.        ,  6.12905021, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
#test_size = len(X) - train_size

#test_size

# %%
x_test = X.values[train_size:len(X)]
x_test
# Out:
# array([[26.24      , 73.        ,  5.97380961, ...,  0.        ,
#          0.        ,  0.        ],
#        [25.42      , 78.        ,  5.65599181, ...,  0.        ,
#          0.        ,  0.        ],
#        [24.6       , 78.        ,  4.89034913, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [13.94      , 61.        ,  5.48479693, ...,  0.        ,
#          0.        ,  0.        ],
#        [13.94      , 61.        ,  5.12396398, ...,  0.        ,
#          0.        ,  0.        ],
#        [13.12      , 66.        ,  4.8598124 , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
#---------------------------------------  Done we divide dependent data (Features) to train and test -------------#

# %%
#------------------------------------  Now we divide independent data (count/ predicted) to train and test ------------#

# %%
y_train = Y.values[0:train_size]
y_train
# Out:
# array([2.56494936, 0.        , 0.        , ..., 6.38012254, 6.12905021,
#        5.97380961])

# %%
y_test = Y.values[train_size:len(Y)]
y_test
# Out:
# array([5.65599181, 4.89034913, 4.36944785, ..., 5.12396398, 4.8598124 ,
#        4.47733681])

# %%
#---------------------------------------  Done we divide independent data (predictd) to train and test -------------#

# %% [markdown]
# ### Fit  and Score the model

# %%
# Linear Regresson
from sklearn.linear_model import LinearRegression
std_reg = LinearRegression()

# Training Process (Fitting) عملية التدريب
std_reg.fit(x_train,y_train)


# calculate the accuracy of Model
r_training = std_reg.score(x_train, y_train) # Accuracy of Training
r_testing = std_reg.score(x_test, y_test)  # Model Accuracy in Testing

r_training
# Out:
# 0.8508375662148083

# %%
# Create Y predction

y_prediction = std_reg.predict(x_test)

y_prediction
# Out:
# array([5.50999896, 5.18082124, 4.36328814, ..., 4.89675418, 4.66006303,
#        4.46784702])

# %%
# Calculate Accuracy - another measure   --- Rout mean Square Error

from sklearn.metrics import mean_squared_error
rmsa_measure = math.sqrt(mean_squared_error(y_test, y_prediction))
rmsa_measure
# Out:
# 0.4887505747115177

# %%
# Calculate RMSLE value and Compare Results -- Another measure

# %% [markdown]
# # -------------------------------------   Thanks A lot -------------------------------------------

# %%
new_data = pd.DataFrame({'Predections':y_prediction})
new_data
# Out:
#       Predections
# 0        5.509999
# 1        5.180821
# 2        4.363288
# 3        3.989942
# 4        3.064400
# ...           ...
# 3260     5.976349
# 3261     5.188778
# 3262     4.896754
# 3263     4.660063
# 3264     4.467847
#
# [3265 rows x 1 columns]

# %%
new_data.to_csv('my_predictions.csv')
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Reda Ibrahim\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Reda Ibrahim\anaconda3\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Reda Ibrahim\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Reda Ibrahim\anaconda3\lib\asyncio\selector_events.py", line 115, in _read_from_self
#     data = self._ssock.recv(4096)
# ...
